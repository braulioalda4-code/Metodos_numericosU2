# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU2/blob/main/Interpolacion_manual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 2 - Interpolación Lineal Manual

# %%
x0 = 1 # Primer punto en x
y0 = 2 # Valor correspondiente en y
x1 = 3 # Segundo punto en x
y1 = 6 # Valor correspondiente en y

x = 2 # Punto donde se desea interpolar

P = y0 + ((y1 - y0) / (x1 - x0)) * (x - x0) # Fórmula de interacion

print("Valor interpolado:", P) # Mostrar resultado
# Out:
# Valor interpolado: 4.0
