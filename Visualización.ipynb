# %% [markdown]
# <a href="https://colab.research.google.com/github/braulioalda4-code/Metodos_numericosU2/blob/main/Visualizaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejericio 3 - Visualización

# %%
a = 1 # Limite inicial inferior
b = 2 # Limite inicial superior
n = 22 # Número de iteraciones

error_teorico = (b - a) / (2**n) # Formula del error máximo en bisección

print("Error máximo después de", n, "iteraciones:", error_teorico) # Mostrar error
# Out:
# Error máximo después de 22 iteraciones: 2.384185791015625e-07
